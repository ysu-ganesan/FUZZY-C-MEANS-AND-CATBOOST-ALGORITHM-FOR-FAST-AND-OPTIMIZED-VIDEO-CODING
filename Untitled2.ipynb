# %%
import cv2

cap= cv2.VideoCapture('C://Users//SRI VAISHNAVI//OneDrive//Documents//jupyter-master//mv.mp4')
success, image = cap.read()
count = 0
while success:
  count += 1
  v = image[200, 300]
  s = sum(v)/len(v)
  print(" Count {}  Pixel at (200, 300) - Value {} ".format(count,v))
  success, image = cap.read()
cap.release()
cv2.destroyAllWindows()
while success:
  count += 1
  for x in range(0,width):
    for y in range(0,height):
      print(image[x,y,z])
# Out:
#  Count 1  Pixel at (200, 300) - Value [119 166 183]
#  Count 2  Pixel at (200, 300) - Value [161 184 203]
#  Count 3  Pixel at (200, 300) - Value [149 166 182]
#  Count 4  Pixel at (200, 300) - Value [167 184 200]
#  Count 5  Pixel at (200, 300) - Value [151 174 195]
#  Count 6  Pixel at (200, 300) - Value [142 162 177]
#  Count 7  Pixel at (200, 300) - Value [140 160 175]
#  Count 8  Pixel at (200, 300) - Value [147 167 182]
#  Count 9  Pixel at (200, 300) - Value [141 167 184]
#  Count 10  Pixel at (200, 300) - Value [153 168 189]
#  Count 11  Pixel at (200, 300) - Value [153 173 193]
#  Count 12  Pixel at (200, 300) - Value [157 172 193]
#  Count 13  Pixel at (200, 300) - Value [157 172 193]
#  Count 14  Pixel at (200, 300) - Value [157 172 193]
#  Count 15  Pixel at (200, 300) - Value [157 172 193]
#  Count 16  Pixel at (200, 300) - Value [157 172 193]
#  Count 17  Pixel at (200, 300) - Value [157 172 193]
#  Count 18  Pixel at (200, 300) - Value [157 172 193]
# ...
