# %% [markdown]
# # FFmpeg demo: video encoding

# %%
# Download a static FFmpeg build and add it to PATH.
r'util/load-ffmpeg.ipynb'
print('Done!')
# Out:
# Done!

# %%
# [optional] Print input video information. You can upload another video file and change the file name below.
# !ffprobe -hide_banner input.mp4
print('Done!')
# Out:
# Done!
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2020-02-18T02:49:23.000000Z
#     encoder         : Google
#   Duration: 00:04:32.95, start: 0.000000, bitrate: 2102 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 1971 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]

# %%
# Compress input.mp4 to a target bitrate and save as output.mp4. 
# Change the command line flags as you need for different encoding settings.

# !ffmpeg -hide_banner -i input.mp4 -b:v 200k -y output.mp4
print('Done!')
# Out:
# Done!
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2020-02-18T02:49:23.000000Z
#     encoder         : Google
#   Duration: 00:04:32.95, start: 0.000000, bitrate: 2102 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 1971 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 000001e352ed4b40] using SAR=1/1
# [libx264 @ 000001e352ed4b40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 000001e352ed4b40] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 000001e352ed4b40] 264 - core 164 r3094 bfc87b7 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=abr mbtree=1 bitrate=200 ratetol=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf59.23.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.27.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.27.100 aac
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   55 fps=0.0 q=0.0 size=       0kB time=00:00:01.90 bitrate=   0.2kbits/s speed=3.41x
# frame=   99 fps= 93 q=61.0 size=       0kB time=00:00:03.29 bitrate=   0.1kbits/s speed=3.09x
# frame=  141 fps= 89 q=62.0 size=       0kB time=00:00:04.69 bitrate=   0.1kbits/s speed=2.95x
# frame=  183 fps= 88 q=60.0 size=       0kB time=00:00:06.31 bitrate=   0.1kbits/s speed=3.03x
# frame=  245 fps= 94 q=58.0 size=       0kB time=00:00:08.40 bitrate=   0.0kbits/s speed=3.23x
# frame=  309 fps= 99 q=55.0 size=     256kB time=00:00:10.28 bitrate= 203.9kbits/s speed=3.31x
# frame=  364 fps=101 q=53.0 size=     256kB time=00:00:12.12 bitrate= 173.1kbits/s speed=3.35x
# frame=  418 fps=101 q=51.0 size=     256kB time=00:00:13.97 bitrate= 150.1kbits/s speed=3.38x
# frame=  463 fps=100 q=51.0 size=     256kB time=00:00:15.39 bitrate= 136.2kbits/s speed=3.32x
# frame=  514 fps= 99 q=51.0 size=     512kB time=00:00:17.22 bitrate= 243.5kbits/s speed=3.33x
# frame=  574 fps=101 q=53.0 size=     512kB time=00:00:19.08 bitrate= 219.8kbits/s speed=3.36x
# frame=  627 fps=102 q=51.0 size=     512kB time=00:00:20.94 bitrate= 200.3kbits/s speed=3.39x
# frame=  687 fps=103 q=50.0 size=     512kB time=00:00:22.82 bitrate= 183.8kbits/s speed=3.41x
# frame=  737 fps=102 q=50.0 size=     768kB time=00:00:24.65 bitrate= 255.1kbits/s speed=3.42x
# frame=  791 fps=103 q=51.0 size=     768kB time=00:00:26.51 bitrate= 237.3kbits/s speed=3.44x
# frame=  848 fps=103 q=52.0 size=     768kB time=00:00:28.37 bitrate= 221.7kbits/s speed=3.45x
# frame=  897 fps=103 q=51.0 size=    1024kB time=00:00:30.23 bitrate= 277.5kbits/s speed=3.46x
# frame=  950 fps=103 q=51.0 size=    1024kB time=00:00:31.67 bitrate= 264.9kbits/s speed=3.43x
# frame= 1006 fps=103 q=52.0 size=    1024kB time=00:00:33.92 bitrate= 247.3kbits/s speed=3.48x
# frame= 1062 fps=104 q=50.0 size=    1024kB time=00:00:35.52 bitrate= 236.1kbits/s speed=3.46x
# frame= 1129 fps=105 q=51.0 size=    1280kB time=00:00:37.66 bitrate= 278.4kbits/s speed= 3.5x
# frame= 1188 fps=105 q=51.0 size=    1280kB time=00:00:39.75 bitrate= 263.8kbits/s speed=3.53x
# frame= 1244 fps=106 q=50.0 size=    1280kB time=00:00:41.72 bitrate= 251.3kbits/s speed=3.54x
# frame= 1296 fps=106 q=50.0 size=    1536kB time=00:00:43.23 bitrate= 291.0kbits/s speed=3.52x
# frame= 1356 fps=106 q=50.0 size=    1536kB time=00:00:45.09 bitrate= 279.1kbits/s speed=3.51x
# frame= 1425 fps=107 q=48.0 size=    1536kB time=00:00:47.76 bitrate= 263.5kbits/s speed=3.58x
# frame= 1514 fps=109 q=47.0 size=    1792kB time=00:00:50.66 bitrate= 289.7kbits/s speed=3.66x
# frame= 1569 fps=109 q=46.0 size=    1792kB time=00:00:52.52 bitrate= 279.5kbits/s speed=3.66x
# frame= 1619 fps=109 q=46.0 size=    1792kB time=00:00:54.12 bitrate= 271.2kbits/s speed=3.64x
# frame= 1675 fps=109 q=46.0 size=    1792kB time=00:00:56.19 bitrate= 261.3kbits/s speed=3.66x
# frame= 1765 fps=111 q=45.0 size=    2048kB time=00:00:59.02 bitrate= 284.2kbits/s speed=3.72x
# frame= 1843 fps=113 q=44.0 size=    2048kB time=00:01:01.37 bitrate= 273.4kbits/s speed=3.75x
# frame= 1911 fps=113 q=44.0 size=    2048kB time=00:01:03.66 bitrate= 263.5kbits/s speed=3.77x
# frame= 1966 fps=113 q=44.0 size=    2048kB time=00:01:05.66 bitrate= 255.5kbits/s speed=3.78x
# frame= 2063 fps=115 q=43.0 size=    2304kB time=00:01:08.77 bitrate= 274.4kbits/s speed=3.84x
# frame= 2116 fps=115 q=43.0 size=    2304kB time=00:01:10.63 bitrate= 267.2kbits/s speed=3.83x
# frame= 2162 fps=114 q=45.0 size=    2560kB time=00:01:12.28 bitrate= 290.1kbits/s speed=3.82x
# frame= 2211 fps=114 q=47.0 size=    2560kB time=00:01:13.88 bitrate= 283.8kbits/s speed= 3.8x
# frame= 2255 fps=113 q=49.0 size=    2816kB time=00:01:15.27 bitrate= 306.4kbits/s speed=3.77x
# frame= 2300 fps=112 q=51.0 size=    2816kB time=00:01:16.67 bitrate= 300.9kbits/s speed=3.75x
# frame= 2350 fps=112 q=51.0 size=    3072kB time=00:01:18.52 bitrate= 320.5kbits/s speed=3.74x
# frame= 2408 fps=112 q=52.0 size=    3072kB time=00:01:20.38 bitrate= 313.1kbits/s speed=3.74x
# frame= 2481 fps=113 q=52.0 size=    3072kB time=00:01:23.05 bitrate= 303.0kbits/s speed=3.78x
# frame= 2535 fps=113 q=48.0 size=    3328kB time=00:01:24.56 bitrate= 322.4kbits/s speed=3.76x
# frame= 2579 fps=112 q=51.0 size=    3328kB time=00:01:26.26 bitrate= 316.1kbits/s speed=3.75x
# frame= 2649 fps=113 q=50.0 size=    3328kB time=00:01:28.30 bitrate= 308.7kbits/s speed=3.76x
# frame= 2719 fps=113 q=49.0 size=    3328kB time=00:01:30.60 bitrate= 300.9kbits/s speed=3.77x
# frame= 2775 fps=113 q=49.0 size=    3328kB time=00:01:32.76 bitrate= 293.9kbits/s speed=3.79x
# frame= 2824 fps=113 q=49.0 size=    3584kB time=00:01:34.31 bitrate= 311.3kbits/s speed=3.77x
# frame= 2878 fps=113 q=49.0 size=    3584kB time=00:01:36.17 bitrate= 305.3kbits/s speed=3.77x
# frame= 2936 fps=113 q=49.0 size=    3584kB time=00:01:38.03 bitrate= 299.5kbits/s speed=3.76x
# frame= 3004 fps=113 q=48.0 size=    3584kB time=00:01:40.35 bitrate= 292.6kbits/s speed=3.78x
# frame= 3066 fps=113 q=48.0 size=    3840kB time=00:01:42.21 bitrate= 307.8kbits/s speed=3.78x
# frame= 3122 fps=113 q=48.0 size=    3840kB time=00:01:44.21 bitrate= 301.9kbits/s speed=3.78x
# frame= 3188 fps=114 q=48.0 size=    4096kB time=00:01:46.39 bitrate= 315.4kbits/s speed=3.79x
# frame= 3234 fps=113 q=48.0 size=    4096kB time=00:01:48.15 bitrate= 310.2kbits/s speed=3.79x
# frame= 3296 fps=113 q=48.0 size=    4096kB time=00:01:50.10 bitrate= 304.7kbits/s speed=3.79x
# frame= 3359 fps=114 q=48.0 size=    4096kB time=00:01:51.96 bitrate= 299.7kbits/s speed=3.79x
# frame= 3416 fps=114 q=48.0 size=    4352kB time=00:01:54.19 bitrate= 312.2kbits/s speed= 3.8x
# frame= 3497 fps=114 q=48.0 size=    4352kB time=00:01:56.68 bitrate= 305.6kbits/s speed=3.81x
# frame= 3581 fps=115 q=46.0 size=    4352kB time=00:01:59.42 bitrate= 298.5kbits/s speed=3.84x
# frame= 3626 fps=115 q=46.0 size=    4352kB time=00:02:01.25 bitrate= 294.0kbits/s speed=3.84x
# frame= 3691 fps=115 q=45.0 size=    4608kB time=00:02:03.11 bitrate= 306.6kbits/s speed=3.83x
# frame= 3742 fps=115 q=45.0 size=    4608kB time=00:02:04.96 bitrate= 302.1kbits/s speed=3.83x
# frame= 3791 fps=114 q=42.0 size=    4608kB time=00:02:06.36 bitrate= 298.7kbits/s speed=3.81x
# frame= 3840 fps=114 q=46.0 size=    4608kB time=00:02:08.22 bitrate= 294.4kbits/s speed=3.81x
# frame= 3889 fps=114 q=45.0 size=    4864kB time=00:02:10.00 bitrate= 306.5kbits/s speed=3.81x
# frame= 3945 fps=114 q=45.0 size=    4864kB time=00:02:11.70 bitrate= 302.5kbits/s speed= 3.8x
# frame= 3994 fps=114 q=46.0 size=    4864kB time=00:02:13.32 bitrate= 298.9kbits/s speed=3.79x
# frame= 4040 fps=113 q=47.0 size=    5120kB time=00:02:15.16 bitrate= 310.3kbits/s speed=3.79x
# frame= 4105 fps=114 q=47.0 size=    5120kB time=00:02:17.04 bitrate= 306.1kbits/s speed=3.79x
# frame= 4166 fps=114 q=47.0 size=    5120kB time=00:02:18.99 bitrate= 301.8kbits/s speed=3.79x
# frame= 4233 fps=114 q=47.0 size=    5376kB time=00:02:21.22 bitrate= 311.8kbits/s speed= 3.8x
# frame= 4292 fps=114 q=46.0 size=    5376kB time=00:02:23.24 bitrate= 307.5kbits/s speed= 3.8x
# frame= 4361 fps=114 q=46.0 size=    5376kB time=00:02:25.40 bitrate= 302.9kbits/s speed=3.81x
# frame= 4457 fps=115 q=44.0 size=    5632kB time=00:02:28.65 bitrate= 310.4kbits/s speed=3.84x
# frame= 4520 fps=115 q=44.0 size=    5632kB time=00:02:30.97 bitrate= 305.6kbits/s speed=3.85x
# frame= 4566 fps=115 q=43.0 size=    5632kB time=00:02:32.36 bitrate= 302.8kbits/s speed=3.83x
# frame= 4619 fps=115 q=43.0 size=    5632kB time=00:02:34.22 bitrate= 299.2kbits/s speed=3.83x
# frame= 4681 fps=115 q=45.0 size=    5888kB time=00:02:36.36 bitrate= 308.5kbits/s speed=3.84x
# frame= 4762 fps=115 q=44.0 size=    5888kB time=00:02:38.87 bitrate= 303.6kbits/s speed=3.85x
# frame= 4807 fps=115 q=44.0 size=    5888kB time=00:02:40.28 bitrate= 300.9kbits/s speed=3.84x
# frame= 4858 fps=115 q=44.0 size=    6144kB time=00:02:42.12 bitrate= 310.5kbits/s speed=3.84x
# frame= 4911 fps=115 q=45.0 size=    6144kB time=00:02:43.97 bitrate= 306.9kbits/s speed=3.83x
# frame= 4970 fps=115 q=45.0 size=    6144kB time=00:02:45.83 bitrate= 303.5kbits/s speed=3.83x
# frame= 5027 fps=115 q=45.0 size=    6400kB time=00:02:47.69 bitrate= 312.6kbits/s speed=3.83x
# frame= 5070 fps=114 q=45.0 size=    6400kB time=00:02:49.20 bitrate= 309.9kbits/s speed=3.82x
# frame= 5118 fps=114 q=46.0 size=    6400kB time=00:02:50.94 bitrate= 306.7kbits/s speed=3.82x
# frame= 5179 fps=114 q=46.0 size=    6656kB time=00:02:52.80 bitrate= 315.5kbits/s speed=3.81x
# frame= 5237 fps=114 q=46.0 size=    6656kB time=00:02:54.66 bitrate= 312.2kbits/s speed=3.81x
# frame= 5280 fps=114 q=46.0 size=    6656kB time=00:02:56.40 bitrate= 309.1kbits/s speed=3.81x
# frame= 5320 fps=114 q=46.0 size=    6656kB time=00:02:57.44 bitrate= 307.3kbits/s speed=3.79x
# frame= 5376 fps=114 q=46.0 size=    6912kB time=00:02:59.30 bitrate= 315.8kbits/s speed=3.79x
# frame= 5441 fps=114 q=46.0 size=    6912kB time=00:03:01.62 bitrate= 311.8kbits/s speed= 3.8x
# frame= 5526 fps=114 q=46.0 size=    6912kB time=00:03:04.41 bitrate= 307.0kbits/s speed=3.81x
# frame= 5585 fps=114 q=46.0 size=    7168kB time=00:03:06.64 bitrate= 314.6kbits/s speed=3.82x
# frame= 5641 fps=114 q=46.0 size=    7168kB time=00:03:08.12 bitrate= 312.1kbits/s speed=3.81x
# frame= 5697 fps=114 q=45.0 size=    7168kB time=00:03:10.33 bitrate= 308.5kbits/s speed=3.82x
# frame= 5785 fps=115 q=45.0 size=    7424kB time=00:03:13.23 bitrate= 314.7kbits/s speed=3.84x
# frame= 5859 fps=115 q=44.0 size=    7424kB time=00:03:15.55 bitrate= 311.0kbits/s speed=3.84x
# frame= 5905 fps=115 q=45.0 size=    7424kB time=00:03:16.95 bitrate= 308.8kbits/s speed=3.83x
# frame= 5953 fps=115 q=46.0 size=    7680kB time=00:03:18.80 bitrate= 316.5kbits/s speed=3.83x
# frame= 6001 fps=114 q=47.0 size=    7680kB time=00:03:20.20 bitrate= 314.3kbits/s speed=3.82x
# frame= 6072 fps=115 q=48.0 size=    7936kB time=00:03:22.96 bitrate= 320.3kbits/s speed=3.83x
# frame= 6156 fps=115 q=47.0 size=    7936kB time=00:03:25.63 bitrate= 316.2kbits/s speed=3.85x
# frame= 6212 fps=115 q=47.0 size=    7936kB time=00:03:27.16 bitrate= 313.8kbits/s speed=3.84x
# frame= 6250 fps=115 q=48.0 size=    8192kB time=00:03:28.56 bitrate= 321.8kbits/s speed=3.83x
# frame= 6296 fps=115 q=49.0 size=    8192kB time=00:03:30.27 bitrate= 319.1kbits/s speed=3.83x
# frame= 6338 fps=114 q=49.0 size=    8448kB time=00:03:31.60 bitrate= 327.1kbits/s speed=3.82x
# frame= 6392 fps=114 q=49.0 size=    8448kB time=00:03:33.20 bitrate= 324.6kbits/s speed=3.81x
# frame= 6450 fps=114 q=50.0 size=    8448kB time=00:03:35.15 bitrate= 321.7kbits/s speed=3.81x
# frame= 6506 fps=114 q=50.0 size=    8704kB time=00:03:37.22 bitrate= 328.3kbits/s speed=3.81x
# frame= 6585 fps=115 q=49.0 size=    8704kB time=00:03:39.70 bitrate= 324.5kbits/s speed=3.82x
# frame= 6645 fps=115 q=49.0 size=    8704kB time=00:03:42.02 bitrate= 321.1kbits/s speed=3.83x
# frame= 6727 fps=115 q=49.0 size=    8704kB time=00:03:44.37 bitrate= 317.8kbits/s speed=3.84x
# frame= 6795 fps=115 q=49.0 size=    8960kB time=00:03:46.67 bitrate= 323.8kbits/s speed=3.84x
# frame= 6865 fps=115 q=48.0 size=    8960kB time=00:03:48.99 bitrate= 320.5kbits/s speed=3.85x
# frame= 6923 fps=115 q=49.0 size=    8960kB time=00:03:51.22 bitrate= 317.4kbits/s speed=3.85x
# frame= 6974 fps=115 q=49.0 size=    9216kB time=00:03:52.71 bitrate= 324.4kbits/s speed=3.85x
# frame= 7026 fps=115 q=50.0 size=    9216kB time=00:03:54.56 bitrate= 321.9kbits/s speed=3.85x
# frame= 7074 fps=115 q=50.0 size=    9472kB time=00:03:56.07 bitrate= 328.7kbits/s speed=3.84x
# frame= 7130 fps=115 q=50.0 size=    9472kB time=00:03:57.81 bitrate= 326.3kbits/s speed=3.83x
# frame= 7181 fps=115 q=51.0 size=    9472kB time=00:03:59.67 bitrate= 323.7kbits/s speed=3.83x
# frame= 7237 fps=115 q=51.0 size=    9728kB time=00:04:01.53 bitrate= 329.9kbits/s speed=3.83x
# frame= 7295 fps=115 q=51.0 size=    9728kB time=00:04:03.39 bitrate= 327.4kbits/s speed=3.83x
# frame= 7352 fps=115 q=51.0 size=    9728kB time=00:04:05.24 bitrate= 324.9kbits/s speed=3.83x
# frame= 7410 fps=115 q=51.0 size=    9984kB time=00:04:07.57 bitrate= 330.4kbits/s speed=3.83x
# frame= 7484 fps=115 q=51.0 size=    9984kB time=00:04:09.89 bitrate= 327.3kbits/s speed=3.84x
# frame= 7548 fps=115 q=50.0 size=    9984kB time=00:04:12.14 bitrate= 324.4kbits/s speed=3.85x
# frame= 7627 fps=115 q=50.0 size=   10240kB time=00:04:14.53 bitrate= 329.6kbits/s speed=3.85x
# frame= 7693 fps=116 q=50.0 size=   10240kB time=00:04:16.85 bitrate= 326.6kbits/s speed=3.86x
# frame= 7769 fps=116 q=50.0 size=   10240kB time=00:04:19.18 bitrate= 323.7kbits/s speed=3.86x
# frame= 7819 fps=116 q=50.0 size=   10496kB time=00:04:21.03 bitrate= 329.4kbits/s speed=3.86x
# frame= 7868 fps=115 q=50.0 size=   10496kB time=00:04:22.43 bitrate= 327.6kbits/s speed=3.85x
# frame= 7925 fps=115 q=50.0 size=   10496kB time=00:04:24.45 bitrate= 325.1kbits/s speed=3.85x
# frame= 8006 fps=116 q=50.0 size=   10752kB time=00:04:27.07 bitrate= 329.8kbits/s speed=3.86x
# frame= 8062 fps=116 q=50.0 size=   10752kB time=00:04:28.95 bitrate= 327.5kbits/s speed=3.86x
# frame= 8113 fps=116 q=50.0 size=   10752kB time=00:04:30.79 bitrate= 325.3kbits/s speed=3.86x
# frame= 8180 fps=116 q=51.0 size=   11008kB time=00:04:32.90 bitrate= 330.4kbits/s speed=3.86x
# frame= 8180 fps=116 q=-1.0 Lsize=   11374kB time=00:04:32.95 bitrate= 341.4kbits/s speed=3.85x
# video:6828kB audio:4258kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.592986%
# [libx264 @ 000001e352ed4b40] frame I:63    Avg QP:37.29  size: 16956
# [libx264 @ 000001e352ed4b40] frame P:2529  Avg QP:41.93  size:  1532
# [libx264 @ 000001e352ed4b40] frame B:5588  Avg QP:45.46  size:   366
# [libx264 @ 000001e352ed4b40] consecutive B-frames:  4.4% 10.5%  9.0% 76.1%
# [libx264 @ 000001e352ed4b40] mb I  I16..4: 23.1% 70.2%  6.7%
# [libx264 @ 000001e352ed4b40] mb P  I16..4:  1.9%  3.9%  0.0%  P16..4: 13.5%  0.6%  0.5%  0.0%  0.0%    skip:79.6%
# [libx264 @ 000001e352ed4b40] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  9.6%  0.1%  0.0%  direct: 0.1%  skip:90.1%  L0:40.0% L1:59.9% BI: 0.1%
# [libx264 @ 000001e352ed4b40] final ratefactor: 42.54
# [libx264 @ 000001e352ed4b40] 8x8 transform intra:67.7% inter:94.3%
# [libx264 @ 000001e352ed4b40] coded y,uvDC,uvAC intra: 14.4% 28.5% 4.6% inter: 0.4% 0.9% 0.0%
# [libx264 @ 000001e352ed4b40] i16 v,h,dc,p: 42% 31%  8% 18%
# [libx264 @ 000001e352ed4b40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17%  9% 60%  2%  2%  2%  2%  2%  2%
# [libx264 @ 000001e352ed4b40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 18% 16%  7%  7%  7%  7%  5%  5%
# [libx264 @ 000001e352ed4b40] i8c dc,h,v,p: 85%  6%  8%  1%
# [libx264 @ 000001e352ed4b40] Weighted P-Frames: Y:3.6% UV:2.7%
# [libx264 @ 000001e352ed4b40] ref P L0: 73.2%  8.3% 13.9%  4.4%  0.2%
# [libx264 @ 000001e352ed4b40] ref B L0: 93.6%  5.1%  1.3%
# [libx264 @ 000001e352ed4b40] ref B L1: 98.2%  1.8%
# [libx264 @ 000001e352ed4b40] kb/s:204.91
# [aac @ 000001e353041440] Qavg: 695.259

# %%
# Display both the source (top) video and encoded (bottom) video.
# Sometimes the two players get out of sync. Press "sync" to mitigate that.

# %run util/play-video.ipynb --ref input.mp4 --tar output.mp4
HTML(html)
# Out:
# <html>
# <style>
# .controls {
#     margin: 0;
#     position: absolute;
#     top: 50%;
#     left: 100%;
#     -ms-transform: translate(-100%, -50%);
#     transform: translate(-100%, -50%);
# }
# button {
#     display: block;
#     padding: 5px 16px;
#     border-radius: 3px;
#     cursor: pointer;
#     background-color: white;
#     border-color: navy;
#     width: 100px;
# }
# </style>
#
# <div>
# <video muted loop controls id='video-ref'>
#   <source src="input.mp4" type="video/mp4">
# </video>
# </div>
# <div class='controls'>
#   <button id='button-play'>Pause</button>
#   <button id='button-sync'>Sync</button>
# </div>
# <div>
# <video muted loop controls id='video-target'>
#   <source src="output.mp4" type="video/mp4">
# </video>
# </div>
#
# <script>
#     var v1 = document.querySelector('#video-ref');
#     var v2 = document.querySelector('#video-target');
#     function seek(sec) {
#       v1.currentTime = sec;
#       v2.currentTime = sec;
#     }
#     document.querySelector('#button-sync').addEventListener('click', (e)=>{
#         seek(v1.currentTime);
#     });
#     document.querySelector('#button-play').addEventListener('click', (e)=>{
#         if (e.target.textContent == 'Pause') {
#             e.target.textContent = 'Resume';
#             v1.pause();
#             v2.pause();
#         } else {
#             e.target.textContent = 'Pause';
#             v1.play();
#             v2.play();
#         }
#     });
#     v1.play();
#     v2.play();
# </script>
# </html>

# %%
# Calculate PSNR between input.mp4 and output.mp4
# !ffmpeg -hide_banner -i output.mp4 -i input.mp4 -lavfi psnr -f null - 2>&1 | grep "Parsed_psnr_0"

# Calculate SSIM between input.mp4 and output.mp4
# !ffmpeg -hide_banner -i output.mp4 -i input.mp4 -lavfi ssim -f null - 2>&1 | grep "Parsed_ssim_0"

# Calculate VMAF between input.mp4 (ref) and output.mp4 (target).
# !ffmpeg -hide_banner -i output.mp4 -i input.mp4 \
  -lavfi "libvmaf=model_path={ffmdir[0]}model/vmaf_v0.6.1.pkl" -f null - 2>&1 | grep 'VMAF' \


print('Done!')
# Out:
# [Parsed_psnr_0 @ 000001f4e3fa5e40] PSNR y:29.911987 u:40.219870 v:39.203926 average:31.449787 min:23.142407 max:97.495941
# [Parsed_ssim_0 @ 0000024402fc19c0] SSIM Y:0.865581 (8.715383) U:0.963291 (14.352286) V:0.957944 (13.761681) All:0.897260 (9.882587)
# Done!
