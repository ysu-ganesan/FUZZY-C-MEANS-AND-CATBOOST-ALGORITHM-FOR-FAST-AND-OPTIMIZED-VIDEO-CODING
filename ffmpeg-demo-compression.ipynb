# %% [markdown]
# # FFmpeg demo: video encoding

# %%
# Download a static FFmpeg build and add it to PATH.
r'util/load-ffmpeg.ipynb'
print('Done!')
# Out:
# Done!

# %%
# [optional] Print input video information. You can upload another video file and change the file name below.
# !ffprobe -hide_banner input.mp4
print('Done!')
# Out:
# Done!
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2020-02-18T02:49:23.000000Z
#     encoder         : Google
#   Duration: 00:04:32.95, start: 0.000000, bitrate: 2102 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 1971 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]

# %%
# Compress input.mp4 to a target bitrate and save as output.mp4. 
# Change the command line flags as you need for different encoding settings.

# !ffmpeg -hide_banner -i input.mp4 -b:v 200k -y output.mp4
print('Done!')
# Out:
# Done!
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2020-02-18T02:49:23.000000Z
#     encoder         : Google
#   Duration: 00:04:32.95, start: 0.000000, bitrate: 2102 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 1971 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 000001daaa684b40] using SAR=1/1
# [libx264 @ 000001daaa684b40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 000001daaa684b40] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 000001daaa684b40] 264 - core 164 r3094 bfc87b7 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=abr mbtree=1 bitrate=200 ratetol=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf59.23.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.27.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2020-02-18T02:49:23.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2020.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.27.100 aac
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   47 fps=0.0 q=0.0 size=       0kB time=00:00:01.90 bitrate=   0.2kbits/s speed=3.29x
# frame=   93 fps= 86 q=62.0 size=       0kB time=00:00:03.29 bitrate=   0.1kbits/s speed=3.05x
# frame=  141 fps= 89 q=62.0 size=       0kB time=00:00:04.99 bitrate=   0.1kbits/s speed=3.15x
# frame=  196 fps= 94 q=60.0 size=       0kB time=00:00:06.54 bitrate=   0.1kbits/s speed=3.14x
# frame=  253 fps= 98 q=58.0 size=     256kB time=00:00:08.70 bitrate= 240.9kbits/s speed=3.37x
# frame=  330 fps=106 q=54.0 size=     256kB time=00:00:11.19 bitrate= 187.4kbits/s speed= 3.6x
# frame=  388 fps=107 q=52.0 size=     256kB time=00:00:13.04 bitrate= 160.7kbits/s speed=3.61x
# frame=  435 fps=106 q=51.0 size=     256kB time=00:00:14.48 bitrate= 144.8kbits/s speed=3.52x
# frame=  477 fps=103 q=52.0 size=     256kB time=00:00:16.27 bitrate= 128.9kbits/s speed=3.53x
# frame=  533 fps=104 q=52.0 size=     512kB time=00:00:17.71 bitrate= 236.8kbits/s speed=3.45x
# frame=  590 fps=105 q=53.0 size=     512kB time=00:00:20.01 bitrate= 209.6kbits/s speed=3.55x
# frame=  659 fps=107 q=51.0 size=     512kB time=00:00:22.12 bitrate= 189.6kbits/s speed=3.61x
# frame=  709 fps=107 q=50.0 size=     768kB time=00:00:23.73 bitrate= 265.1kbits/s speed=3.58x
# frame=  757 fps=106 q=50.0 size=     768kB time=00:00:25.28 bitrate= 248.8kbits/s speed=3.55x
# frame=  821 fps=107 q=52.0 size=     768kB time=00:00:27.44 bitrate= 229.2kbits/s speed=3.59x
# frame=  883 fps=108 q=51.0 size=    1024kB time=00:00:29.69 bitrate= 282.5kbits/s speed=3.65x
# frame=  936 fps=108 q=50.0 size=    1024kB time=00:00:31.16 bitrate= 269.2kbits/s speed= 3.6x
# frame=  992 fps=108 q=52.0 size=    1024kB time=00:00:33.20 bitrate= 252.6kbits/s speed=3.63x
# frame= 1048 fps=109 q=51.0 size=    1024kB time=00:00:35.20 bitrate= 238.3kbits/s speed=3.65x
# frame= 1103 fps=109 q=51.0 size=    1280kB time=00:00:36.73 bitrate= 285.5kbits/s speed=3.62x
# frame= 1173 fps=110 q=50.0 size=    1280kB time=00:00:39.05 bitrate= 268.5kbits/s speed=3.66x
# frame= 1224 fps=110 q=50.0 size=    1280kB time=00:00:40.91 bitrate= 256.3kbits/s speed=3.66x
# frame= 1279 fps=109 q=50.0 size=    1280kB time=00:00:42.77 bitrate= 245.2kbits/s speed=3.66x
# frame= 1338 fps=110 q=50.0 size=    1536kB time=00:00:44.62 bitrate= 282.0kbits/s speed=3.66x
# frame= 1400 fps=110 q=49.0 size=    1536kB time=00:00:46.95 bitrate= 268.0kbits/s speed= 3.7x
# frame= 1469 fps=111 q=47.0 size=    1536kB time=00:00:49.27 bitrate= 255.4kbits/s speed=3.73x
# frame= 1542 fps=112 q=45.0 size=    1792kB time=00:00:51.59 bitrate= 284.5kbits/s speed=3.76x
# frame= 1597 fps=112 q=46.0 size=    1792kB time=00:00:53.45 bitrate= 274.6kbits/s speed=3.75x
# frame= 1652 fps=112 q=46.0 size=    1792kB time=00:00:55.30 bitrate= 265.4kbits/s speed=3.75x
# frame= 1715 fps=113 q=46.0 size=    2048kB time=00:00:57.16 bitrate= 293.5kbits/s speed=3.75x
# frame= 1801 fps=114 q=44.0 size=    2048kB time=00:01:00.18 bitrate= 278.8kbits/s speed=3.82x
# frame= 1880 fps=116 q=44.0 size=    2048kB time=00:01:02.74 bitrate= 267.4kbits/s speed=3.86x
# frame= 1939 fps=116 q=44.0 size=    2048kB time=00:01:05.03 bitrate= 258.0kbits/s speed=3.88x
# frame= 2043 fps=118 q=44.0 size=    2304kB time=00:01:08.31 bitrate= 276.3kbits/s speed=3.96x
# frame= 2096 fps=118 q=43.0 size=    2304kB time=00:01:10.17 bitrate= 269.0kbits/s speed=3.95x
# frame= 2148 fps=118 q=45.0 size=    2560kB time=00:01:11.58 bitrate= 293.0kbits/s speed=3.92x
# frame= 2199 fps=117 q=46.0 size=    2560kB time=00:01:13.42 bitrate= 285.6kbits/s speed=3.91x
# frame= 2242 fps=116 q=48.0 size=    2816kB time=00:01:14.81 bitrate= 308.3kbits/s speed=3.87x
# frame= 2286 fps=115 q=50.0 size=    2816kB time=00:01:16.20 bitrate= 302.7kbits/s speed=3.85x
# frame= 2338 fps=115 q=51.0 size=    3072kB time=00:01:18.06 bitrate= 322.4kbits/s speed=3.84x
# frame= 2393 fps=115 q=52.0 size=    3072kB time=00:01:19.92 bitrate= 314.9kbits/s speed=3.84x
# frame= 2463 fps=115 q=52.0 size=    3072kB time=00:01:22.24 bitrate= 306.0kbits/s speed=3.85x
# frame= 2523 fps=115 q=51.0 size=    3328kB time=00:01:24.12 bitrate= 324.1kbits/s speed=3.85x
# frame= 2562 fps=115 q=51.0 size=    3328kB time=00:01:25.49 bitrate= 318.9kbits/s speed=3.82x
# frame= 2619 fps=115 q=50.0 size=    3328kB time=00:01:27.35 bitrate= 312.1kbits/s speed=3.82x
# frame= 2679 fps=115 q=50.0 size=    3328kB time=00:01:29.67 bitrate= 304.0kbits/s speed=3.84x
# frame= 2739 fps=115 q=49.0 size=    3328kB time=00:01:31.53 bitrate= 297.9kbits/s speed=3.83x
# frame= 2792 fps=114 q=49.0 size=    3328kB time=00:01:33.39 bitrate= 291.9kbits/s speed=3.83x
# frame= 2844 fps=114 q=49.0 size=    3584kB time=00:01:34.78 bitrate= 309.8kbits/s speed=3.81x
# frame= 2900 fps=114 q=49.0 size=    3584kB time=00:01:36.64 bitrate= 303.8kbits/s speed= 3.8x
# frame= 2955 fps=114 q=48.0 size=    3584kB time=00:01:38.89 bitrate= 296.9kbits/s speed=3.81x
# frame= 3020 fps=114 q=48.0 size=    3840kB time=00:01:40.82 bitrate= 312.0kbits/s speed=3.81x
# frame= 3080 fps=114 q=48.0 size=    3840kB time=00:01:42.67 bitrate= 306.4kbits/s speed=3.81x
# frame= 3128 fps=114 q=48.0 size=    3840kB time=00:01:44.53 bitrate= 300.9kbits/s speed=3.81x
# frame= 3188 fps=114 q=48.0 size=    4096kB time=00:01:46.39 bitrate= 315.4kbits/s speed= 3.8x
# frame= 3234 fps=114 q=48.0 size=    4096kB time=00:01:47.83 bitrate= 311.2kbits/s speed=3.79x
# frame= 3290 fps=114 q=48.0 size=    4096kB time=00:01:49.83 bitrate= 305.5kbits/s speed=3.79x
# frame= 3359 fps=114 q=48.0 size=    4096kB time=00:01:51.96 bitrate= 299.7kbits/s speed= 3.8x
# frame= 3416 fps=114 q=48.0 size=    4352kB time=00:01:54.10 bitrate= 312.5kbits/s speed= 3.8x
# frame= 3497 fps=115 q=48.0 size=    4352kB time=00:01:56.63 bitrate= 305.7kbits/s speed=3.82x
# frame= 3578 fps=115 q=46.0 size=    4352kB time=00:01:59.39 bitrate= 298.6kbits/s speed=3.85x
# frame= 3623 fps=115 q=46.0 size=    4352kB time=00:02:00.83 bitrate= 295.0kbits/s speed=3.83x
# frame= 3687 fps=115 q=45.0 size=    4608kB time=00:02:03.11 bitrate= 306.6kbits/s speed=3.84x
# frame= 3735 fps=115 q=45.0 size=    4608kB time=00:02:04.92 bitrate= 302.2kbits/s speed=3.84x
# frame= 3791 fps=115 q=42.0 size=    4608kB time=00:02:06.38 bitrate= 298.7kbits/s speed=3.82x
# frame= 3834 fps=114 q=45.0 size=    4608kB time=00:02:08.22 bitrate= 294.4kbits/s speed=3.82x
# frame= 3889 fps=114 q=45.0 size=    4864kB time=00:02:09.96 bitrate= 306.6kbits/s speed=3.82x
# frame= 3945 fps=114 q=45.0 size=    4864kB time=00:02:11.56 bitrate= 302.9kbits/s speed=3.81x
# frame= 3995 fps=114 q=46.0 size=    4864kB time=00:02:13.32 bitrate= 298.9kbits/s speed= 3.8x
# frame= 4040 fps=113 q=47.0 size=    5120kB time=00:02:15.16 bitrate= 310.3kbits/s speed= 3.8x
# frame= 4107 fps=114 q=47.0 size=    5120kB time=00:02:17.04 bitrate= 306.1kbits/s speed= 3.8x
# frame= 4166 fps=114 q=47.0 size=    5120kB time=00:02:19.04 bitrate= 301.7kbits/s speed= 3.8x
# frame= 4236 fps=114 q=47.0 size=    5376kB time=00:02:21.22 bitrate= 311.8kbits/s speed= 3.8x
# frame= 4299 fps=114 q=46.0 size=    5376kB time=00:02:23.54 bitrate= 306.8kbits/s speed=3.81x
# frame= 4363 fps=114 q=46.0 size=    5376kB time=00:02:25.86 bitrate= 301.9kbits/s speed=3.82x
# frame= 4460 fps=115 q=41.0 size=    5632kB time=00:02:29.02 bitrate= 309.6kbits/s speed=3.86x
# frame= 4527 fps=116 q=44.0 size=    5632kB time=00:02:31.02 bitrate= 305.5kbits/s speed=3.86x
# frame= 4566 fps=115 q=43.0 size=    5632kB time=00:02:32.36 bitrate= 302.8kbits/s speed=3.84x
# frame= 4611 fps=115 q=44.0 size=    5632kB time=00:02:33.76 bitrate= 300.1kbits/s speed=3.83x
# frame= 4667 fps=115 q=45.0 size=    5632kB time=00:02:35.64 bitrate= 296.4kbits/s speed=3.83x
# frame= 4731 fps=115 q=44.0 size=    5888kB time=00:02:37.94 bitrate= 305.4kbits/s speed=3.84x
# frame= 4786 fps=115 q=44.0 size=    5888kB time=00:02:39.79 bitrate= 301.8kbits/s speed=3.83x
# frame= 4834 fps=115 q=44.0 size=    5888kB time=00:02:41.19 bitrate= 299.2kbits/s speed=3.82x
# frame= 4877 fps=114 q=45.0 size=    6144kB time=00:02:42.67 bitrate= 309.4kbits/s speed=3.81x
# frame= 4933 fps=114 q=45.0 size=    6144kB time=00:02:44.51 bitrate= 305.9kbits/s speed=3.81x
# frame= 4988 fps=114 q=46.0 size=    6144kB time=00:02:46.57 bitrate= 302.1kbits/s speed=3.81x
# frame= 5042 fps=114 q=45.0 size=    6400kB time=00:02:48.20 bitrate= 311.7kbits/s speed=3.81x
# frame= 5090 fps=114 q=46.0 size=    6400kB time=00:02:50.01 bitrate= 308.4kbits/s speed= 3.8x
# frame= 5140 fps=114 q=46.0 size=    6400kB time=00:02:51.75 bitrate= 305.3kbits/s speed= 3.8x
# frame= 5208 fps=114 q=46.0 size=    6656kB time=00:02:53.73 bitrate= 313.9kbits/s speed= 3.8x
# frame= 5266 fps=114 q=46.0 size=    6656kB time=00:02:55.96 bitrate= 309.9kbits/s speed=3.81x
# frame= 5308 fps=114 q=46.0 size=    6656kB time=00:02:57.42 bitrate= 307.3kbits/s speed= 3.8x
# frame= 5364 fps=114 q=46.0 size=    6912kB time=00:02:59.09 bitrate= 316.2kbits/s speed=3.79x
# frame= 5419 fps=114 q=45.0 size=    6912kB time=00:03:00.69 bitrate= 313.4kbits/s speed=3.79x
# frame= 5489 fps=114 q=46.0 size=    6912kB time=00:03:03.01 bitrate= 309.4kbits/s speed= 3.8x
# frame= 5557 fps=114 q=46.0 size=    7168kB time=00:03:05.55 bitrate= 316.5kbits/s speed=3.81x
# frame= 5613 fps=114 q=46.0 size=    7168kB time=00:03:07.31 bitrate= 313.5kbits/s speed=3.81x
# frame= 5681 fps=114 q=45.0 size=    7168kB time=00:03:09.52 bitrate= 309.8kbits/s speed=3.81x
# frame= 5739 fps=114 q=46.0 size=    7168kB time=00:03:11.51 bitrate= 306.6kbits/s speed=3.81x
# frame= 5823 fps=115 q=44.0 size=    7424kB time=00:03:14.56 bitrate= 312.6kbits/s speed=3.83x
# frame= 5873 fps=115 q=44.0 size=    7424kB time=00:03:16.02 bitrate= 310.3kbits/s speed=3.83x
# frame= 5918 fps=114 q=45.0 size=    7424kB time=00:03:17.41 bitrate= 308.1kbits/s speed=3.81x
# frame= 5962 fps=114 q=46.0 size=    7680kB time=00:03:18.80 bitrate= 316.5kbits/s speed= 3.8x
# frame= 6016 fps=114 q=47.0 size=    7680kB time=00:03:20.66 bitrate= 313.5kbits/s speed= 3.8x
# frame= 6086 fps=114 q=48.0 size=    7936kB time=00:03:23.31 bitrate= 319.8kbits/s speed=3.81x
# frame= 6161 fps=114 q=47.0 size=    7936kB time=00:03:25.77 bitrate= 315.9kbits/s speed=3.82x
# frame= 6212 fps=114 q=47.0 size=    7936kB time=00:03:27.30 bitrate= 313.6kbits/s speed=3.82x
# frame= 6254 fps=114 q=48.0 size=    8192kB time=00:03:28.65 bitrate= 321.6kbits/s speed=3.81x
# frame= 6299 fps=114 q=49.0 size=    8192kB time=00:03:30.41 bitrate= 318.9kbits/s speed= 3.8x
# frame= 6344 fps=114 q=49.0 size=    8448kB time=00:03:31.81 bitrate= 326.7kbits/s speed=3.79x
# frame= 6394 fps=113 q=49.0 size=    8448kB time=00:03:33.20 bitrate= 324.6kbits/s speed=3.78x
# frame= 6450 fps=113 q=50.0 size=    8448kB time=00:03:35.36 bitrate= 321.3kbits/s speed=3.79x
# frame= 6506 fps=113 q=50.0 size=    8704kB time=00:03:37.17 bitrate= 328.3kbits/s speed=3.79x
# frame= 6573 fps=114 q=49.0 size=    8704kB time=00:03:39.61 bitrate= 324.7kbits/s speed= 3.8x
# frame= 6639 fps=114 q=49.0 size=    8704kB time=00:03:41.56 bitrate= 321.8kbits/s speed= 3.8x
# frame= 6707 fps=114 q=49.0 size=    8704kB time=00:03:43.88 bitrate= 318.5kbits/s speed= 3.8x
# frame= 6774 fps=114 q=49.0 size=    8960kB time=00:03:46.20 bitrate= 324.5kbits/s speed=3.81x
# frame= 6838 fps=114 q=49.0 size=    8960kB time=00:03:48.06 bitrate= 321.8kbits/s speed=3.81x
# frame= 6907 fps=114 q=48.0 size=    8960kB time=00:03:50.38 bitrate= 318.6kbits/s speed=3.82x
# frame= 6951 fps=114 q=49.0 size=    9216kB time=00:03:52.10 bitrate= 325.3kbits/s speed=3.81x
# frame= 7003 fps=114 q=49.0 size=    9216kB time=00:03:53.63 bitrate= 323.1kbits/s speed=3.81x
# frame= 7054 fps=114 q=50.0 size=    9216kB time=00:03:55.49 bitrate= 320.6kbits/s speed= 3.8x
# frame= 7102 fps=114 q=50.0 size=    9472kB time=00:03:57.12 bitrate= 327.2kbits/s speed= 3.8x
# frame= 7158 fps=114 q=50.0 size=    9472kB time=00:03:58.77 bitrate= 325.0kbits/s speed= 3.8x
# frame= 7206 fps=114 q=51.0 size=    9728kB time=00:04:00.60 bitrate= 331.2kbits/s speed= 3.8x
# frame= 7267 fps=114 q=51.0 size=    9728kB time=00:04:02.46 bitrate= 328.7kbits/s speed=3.79x
# frame= 7323 fps=114 q=51.0 size=    9728kB time=00:04:04.32 bitrate= 326.2kbits/s speed=3.79x
# frame= 7382 fps=114 q=51.0 size=    9984kB time=00:04:06.38 bitrate= 332.0kbits/s speed=3.79x
# frame= 7447 fps=114 q=51.0 size=    9984kB time=00:04:08.49 bitrate= 329.1kbits/s speed= 3.8x
# frame= 7522 fps=114 q=50.0 size=    9984kB time=00:04:10.84 bitrate= 326.1kbits/s speed= 3.8x
# frame= 7594 fps=114 q=50.0 size=    9984kB time=00:04:13.60 bitrate= 322.5kbits/s speed=3.82x
# frame= 7659 fps=114 q=50.0 size=   10240kB time=00:04:15.46 bitrate= 328.4kbits/s speed=3.82x
# frame= 7729 fps=115 q=50.0 size=   10240kB time=00:04:18.08 bitrate= 325.0kbits/s speed=3.83x
# frame= 7794 fps=115 q=50.0 size=   10240kB time=00:04:20.10 bitrate= 322.5kbits/s speed=3.83x
# frame= 7842 fps=115 q=50.0 size=   10496kB time=00:04:21.96 bitrate= 328.2kbits/s speed=3.83x
# frame= 7894 fps=114 q=50.0 size=   10496kB time=00:04:23.36 bitrate= 326.5kbits/s speed=3.82x
# frame= 7965 fps=115 q=51.0 size=   10752kB time=00:04:25.68 bitrate= 331.5kbits/s speed=3.82x
# frame= 8034 fps=115 q=50.0 size=   10752kB time=00:04:28.00 bitrate= 328.7kbits/s speed=3.83x
# frame= 8089 fps=115 q=50.0 size=   10752kB time=00:04:29.86 bitrate= 326.4kbits/s speed=3.83x
# frame= 8146 fps=115 q=50.0 size=   10752kB time=00:04:31.74 bitrate= 324.1kbits/s speed=3.82x
# frame= 8180 fps=114 q=-1.0 Lsize=   11374kB time=00:04:32.95 bitrate= 341.4kbits/s speed=3.82x
# video:6828kB audio:4258kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.592986%
# [libx264 @ 000001daaa684b40] frame I:63    Avg QP:37.29  size: 16956
# [libx264 @ 000001daaa684b40] frame P:2529  Avg QP:41.93  size:  1532
# [libx264 @ 000001daaa684b40] frame B:5588  Avg QP:45.46  size:   366
# [libx264 @ 000001daaa684b40] consecutive B-frames:  4.4% 10.5%  9.0% 76.1%
# [libx264 @ 000001daaa684b40] mb I  I16..4: 23.1% 70.2%  6.7%
# [libx264 @ 000001daaa684b40] mb P  I16..4:  1.9%  3.9%  0.0%  P16..4: 13.5%  0.6%  0.5%  0.0%  0.0%    skip:79.6%
# [libx264 @ 000001daaa684b40] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  9.6%  0.1%  0.0%  direct: 0.1%  skip:90.1%  L0:40.0% L1:59.9% BI: 0.1%
# [libx264 @ 000001daaa684b40] final ratefactor: 42.54
# [libx264 @ 000001daaa684b40] 8x8 transform intra:67.7% inter:94.3%
# [libx264 @ 000001daaa684b40] coded y,uvDC,uvAC intra: 14.4% 28.5% 4.6% inter: 0.4% 0.9% 0.0%
# [libx264 @ 000001daaa684b40] i16 v,h,dc,p: 42% 31%  8% 18%
# [libx264 @ 000001daaa684b40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17%  9% 60%  2%  2%  2%  2%  2%  2%
# [libx264 @ 000001daaa684b40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 18% 16%  7%  7%  7%  7%  5%  5%
# [libx264 @ 000001daaa684b40] i8c dc,h,v,p: 85%  6%  8%  1%
# [libx264 @ 000001daaa684b40] Weighted P-Frames: Y:3.6% UV:2.7%
# [libx264 @ 000001daaa684b40] ref P L0: 73.2%  8.3% 13.9%  4.4%  0.2%
# [libx264 @ 000001daaa684b40] ref B L0: 93.6%  5.1%  1.3%
# [libx264 @ 000001daaa684b40] ref B L1: 98.2%  1.8%
# [libx264 @ 000001daaa684b40] kb/s:204.91
# [aac @ 000001daaa7f1440] Qavg: 695.259

# %%
# Display both the source (top) video and encoded (bottom) video.
# Sometimes the two players get out of sync. Press "sync" to mitigate that.

# %run util/play-video.ipynb --ref input.mp4 --tar output.mp4
HTML(html)
# Out:
# <html>
# <style>
# .controls {
#     margin: 0;
#     position: absolute;
#     top: 50%;
#     left: 100%;
#     -ms-transform: translate(-100%, -50%);
#     transform: translate(-100%, -50%);
# }
# button {
#     display: block;
#     padding: 5px 16px;
#     border-radius: 3px;
#     cursor: pointer;
#     background-color: white;
#     border-color: navy;
#     width: 100px;
# }
# </style>
#
# <div>
# <video muted loop controls id='video-ref'>
#   <source src="input.mp4" type="video/mp4">
# </video>
# </div>
# <div class='controls'>
#   <button id='button-play'>Pause</button>
#   <button id='button-sync'>Sync</button>
# </div>
# <div>
# <video muted loop controls id='video-target'>
#   <source src="output.mp4" type="video/mp4">
# </video>
# </div>
#
# <script>
#     var v1 = document.querySelector('#video-ref');
#     var v2 = document.querySelector('#video-target');
#     function seek(sec) {
#       v1.currentTime = sec;
#       v2.currentTime = sec;
#     }
#     document.querySelector('#button-sync').addEventListener('click', (e)=>{
#         seek(v1.currentTime);
#     });
#     document.querySelector('#button-play').addEventListener('click', (e)=>{
#         if (e.target.textContent == 'Pause') {
#             e.target.textContent = 'Resume';
#             v1.pause();
#             v2.pause();
#         } else {
#             e.target.textContent = 'Pause';
#             v1.play();
#             v2.play();
#         }
#     });
#     v1.play();
#     v2.play();
# </script>
# </html>

# %%
# Calculate PSNR between input.mp4 and output.mp4
# !ffmpeg -hide_banner -i output.mp4 -i input.mp4 -lavfi psnr -f null - 2>&1 | grep "Parsed_psnr_0"

# Calculate SSIM between input.mp4 and output.mp4
# !ffmpeg -hide_banner -i output.mp4 -i input.mp4 -lavfi ssim -f null - 2>&1 | grep "Parsed_ssim_0"

# Calculate VMAF between input.mp4 (ref) and output.mp4 (target).
# !ffmpeg -hide_banner -i output.mp4 -i input.mp4 \
  -lavfi "libvmaf=model_path={ffmdir[0]}model/vmaf_v0.6.1.pkl" -f null - 2>&1 | grep 'VMAF' \


print('Done!')
# Out:
# [Parsed_psnr_0 @ 000001e6211e7b80] PSNR y:29.911987 u:40.219870 v:39.203926 average:31.449787 min:23.142407 max:97.495941
# [Parsed_ssim_0 @ 000002674e81ca40] SSIM Y:0.865581 (8.715383) U:0.963291 (14.352286) V:0.957944 (13.761681) All:0.897260 (9.882587)
# Done!
